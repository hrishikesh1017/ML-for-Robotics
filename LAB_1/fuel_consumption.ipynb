# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("FuelConsumption.csv")
df.head(5)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %% [markdown]
# Histogram To Visualize Data

# %%
df.hist(bins=10, figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'MODELYEAR'}>,
#         <Axes: title={'center': 'ENGINESIZE'}>,
#         <Axes: title={'center': 'CYLINDERS'}>],
#        [<Axes: title={'center': 'FUELCONSUMPTION_CITY'}>,
#         <Axes: title={'center': 'FUELCONSUMPTION_HWY'}>,
#         <Axes: title={'center': 'FUELCONSUMPTION_COMB'}>],
#        [<Axes: title={'center': 'FUELCONSUMPTION_COMB_MPG'}>,
#         <Axes: title={'center': 'CO2EMISSIONS'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Removing Model Year as no signifact value other than 2014

# %%
df.drop(columns=["MODELYEAR"], axis=1, inplace=True)

# %%
df.head()
# Out:
#     MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA         ILX      COMPACT         2.0          4          AS5
# 1  ACURA         ILX      COMPACT         2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6          AS6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
# 2        Z                   6.0                  5.8                   5.9
# 3        Z                  12.7                  9.1                  11.1
# 4        Z                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# ...

# %% [markdown]
# Categeorical Columns

# %%
cat_columns = ["MAKE","MODEL","VEHICLECLASS","TRANSMISSION","FUELTYPE"]
for i in cat_columns:
    print(df[cat_columns].nunique())
# Out:
# MAKE             39
# MODEL           663
# VEHICLECLASS     16
# TRANSMISSION     22
# FUELTYPE          4
# dtype: int64
# MAKE             39
# MODEL           663
# VEHICLECLASS     16
# TRANSMISSION     22
# FUELTYPE          4
# dtype: int64
# MAKE             39
# MODEL           663
# VEHICLECLASS     16
# TRANSMISSION     22
# FUELTYPE          4
# dtype: int64
# MAKE             39
# MODEL           663
# VEHICLECLASS     16
# TRANSMISSION     22
# FUELTYPE          4
# dtype: int64
# MAKE             39
# MODEL           663
# VEHICLECLASS     16
# TRANSMISSION     22
# FUELTYPE          4
# dtype: int64

# %% [markdown]
# One Hot Encoding The FUELTYPE Column as it has only 4 unique values

# %%
df = pd.get_dummies(df,columns=["FUELTYPE"], drop_first=True)

# %%
target_column = df.pop('CO2EMISSIONS')

# Insert the 'target' column at the last position
df['CO2EMISSIONS'] = target_column

# %%
df
# Out:
#        MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0     ACURA         ILX         COMPACT         2.0          4          AS5
# 1     ACURA         ILX         COMPACT         2.4          4           M6
# 2     ACURA  ILX HYBRID         COMPACT         1.5          4          AV7
# 3     ACURA     MDX 4WD     SUV - SMALL         3.5          6          AS6
# 4     ACURA     RDX AWD     SUV - SMALL         3.5          6          AS6
# ...     ...         ...             ...         ...        ...          ...
# 1062  VOLVO    XC60 AWD     SUV - SMALL         3.0          6          AS6
# 1063  VOLVO    XC60 AWD     SUV - SMALL         3.2          6          AS6
# 1064  VOLVO    XC70 AWD     SUV - SMALL         3.0          6          AS6
# 1065  VOLVO    XC70 AWD     SUV - SMALL         3.2          6          AS6
# 1066  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6          AS6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MAKE                      1067 non-null   object
#  1   MODEL                     1067 non-null   object
#  2   VEHICLECLASS              1067 non-null   object
#  3   ENGINESIZE                1067 non-null   float64
#  4   CYLINDERS                 1067 non-null   int64
#  5   TRANSMISSION              1067 non-null   object
#  6   FUELCONSUMPTION_CITY      1067 non-null   float64
#  7   FUELCONSUMPTION_HWY       1067 non-null   float64
#  8   FUELCONSUMPTION_COMB      1067 non-null   float64
#  9   FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  10  FUELTYPE_E                1067 non-null   bool
#  11  FUELTYPE_X                1067 non-null   bool
#  12  FUELTYPE_Z                1067 non-null   bool
# ...

# %%
l1 = []
for i in df.columns:
    if df[i].dtypes == 'int64' or df[i].dtypes == 'float64' or df[i].dtypes == 'bool':
        l1.append(i)

# %%
numeric_df = df[l1]

# %%
numeric_df
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  FUELTYPE_E  FUELTYPE_X  \
# ...

# %% [markdown]
# Correlation Matrix

# %%
corr = numeric_df.iloc[:,:-1].corr()

# %%
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)

# Add a title (optional)
plt.title('Correlation Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# Function To Remove Highly Correlated Columns

# %%
def correlation(dataset, threshold):
  col_cor = set()
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold:
        colname = corr_matrix.columns[i]
        col_cor.add(colname)
  return col_cor

# %%
corr_cols=  correlation(numeric_df.iloc[:,:-1], 0.9)

# %%
corr_cols
# Out:
# {'CYLINDERS',
#  'FUELCONSUMPTION_COMB',
#  'FUELCONSUMPTION_COMB_MPG',
#  'FUELCONSUMPTION_HWY'}

# %%
dataset = numeric_df.drop(columns=corr_cols, axis=1)
dataset
# Out:
#       ENGINESIZE  FUELCONSUMPTION_CITY  FUELTYPE_E  FUELTYPE_X  FUELTYPE_Z  \
# 0            2.0                   9.9       False       False        True
# 1            2.4                  11.2       False       False        True
# 2            1.5                   6.0       False       False        True
# 3            3.5                  12.7       False       False        True
# 4            3.5                  12.1       False       False        True
# ...          ...                   ...         ...         ...         ...
# 1062         3.0                  13.4       False        True       False
# 1063         3.2                  13.2       False        True       False
# 1064         3.0                  13.4       False        True       False
# 1065         3.2                  12.9       False        True       False
# 1066         3.2                  14.9       False        True       False
#
#       CO2EMISSIONS
# 0              196
# 1              221
# ...

# %% [markdown]
# Visualizing and applying Transformations To Normalize

# %%
dataset['FUELTYPE_E'] = dataset['FUELTYPE_E'].astype(int)
dataset['FUELTYPE_X'] = dataset['FUELTYPE_X'].astype(int)
dataset['FUELTYPE_Z'] = dataset['FUELTYPE_Z'].astype(int)

# %% [markdown]
# Outlier Detection And Removal

# %%
def remove_outliers_using_boxplot(df, column):

    # Visualize the boxplot
    plt.figure(figsize=(10, 6))
    plt.boxplot(df[column], vert=False)
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    plt.show()
    
    # Calculate the IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Determine the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Remove outliers
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_filtered

# %%
cleaned_df = remove_outliers_using_boxplot(dataset, "ENGINESIZE")

# %%
cleaned_df = remove_outliers_using_boxplot(cleaned_df, "FUELCONSUMPTION_CITY")

# %% [markdown]
# Train Test Splitting

# %%
X = cleaned_df.iloc[:,:-1].values
Y = cleaned_df.iloc[:,-1].values
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.1,random_state=42)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train[:,0:] = sc.fit_transform(x_train[:,0:])
x_test[:,0:] = sc.transform(x_test[:,0:])

# %% [markdown]
# Training Using Linear Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([326.42603472, 249.26655332, 162.8556818 , 187.55345511,
#        313.27216462, 181.92185147, 237.99180752, 245.45061217,
#        194.8007949 , 223.26258607, 213.82657978, 200.68424819,
#        174.34766172, 277.82065257, 207.85658766, 268.11548887,
#        264.29954772, 174.40535427, 384.74811908, 432.04730729,
#        195.03533678, 273.99894217, 238.28981121, 202.23075327,
#        285.94444952, 143.92020742, 354.96282621, 190.93293045,
#        202.54029547, 281.30974376, 268.46541586, 177.77906035,
#        311.66796699, 306.03059409, 195.03533678, 238.0206538 ,
#        251.51291237, 125.54812247, 249.63378807, 330.12659077,
#        234.23355892, 213.86696457, 360.60019911, 313.64516863,
#        168.72759658, 224.80332189, 200.70732521, 191.25401116,
#        210.10294671, 269.97730541, 213.86119531, 230.75023699,
#        189.05380615, 356.47471575, 234.23355892, 349.28506852,
#        250.22954931, 283.45225622, 322.73701718, 175.89993605,
# ...

# %% [markdown]
# Evaluation Using Linear Regressor

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test,y_pred)

# %%
print("r2 score = ",r2)
print("mean_squared_error = ",mse)
# Out:
# r2 score =  0.9839550458820034
# mean_squared_error =  59.62138655928306

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_prediction_vs_actual(y_test, y_pred):


    plt.figure(figsize=(8, 6))

    # Scatter plot
    plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
    
    # Add 45-degree line
    min_val = min(min(y_test), min(y_pred))
    max_val = max(max(y_test), max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Fit')

    # Labels and title
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Prediction vs Actual')
    plt.legend()
    
    # Show plot
    plt.grid(True)
    plt.show()


plot_prediction_vs_actual(y_test, y_pred)

# %% [markdown]
# Training Using Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %% [markdown]
# Evaluation Using Random Forest Regressor

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test,y_pred)

# %%
print("r2 score = ",r2)
print("mean_squared_error = ",mse)
# Out:
# r2 score =  0.9902966780011864
# mean_squared_error =  36.05653886860113

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_prediction_vs_actual(y_test, y_pred):


    plt.figure(figsize=(8, 6))

    # Scatter plot
    plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
    
    # Add 45-degree line
    min_val = min(min(y_test), min(y_pred))
    max_val = max(max(y_test), max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Fit')

    # Labels and title
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Prediction vs Actual')
    plt.legend()
    
    # Show plot
    plt.grid(True)
    plt.show()


plot_prediction_vs_actual(y_test, y_pred)

# %% [markdown]
# Training Using Support Vector Machine

# %%
from sklearn.svm import SVR
model = SVR(kernel='linear')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %% [markdown]
# Evaluation Using Support Vector Machine

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test,y_pred)

# %%
print("r2 score = ",r2)
print("mean_squared_error = ",mse)
# Out:
# r2 score =  0.9829550271173123
# mean_squared_error =  63.33735264417882

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_prediction_vs_actual(y_test, y_pred):


    plt.figure(figsize=(8, 6))

    # Scatter plot
    plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
    
    # Add 45-degree line
    min_val = min(min(y_test), min(y_pred))
    max_val = max(max(y_test), max(y_pred))
    plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Fit')

    # Labels and title
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Prediction vs Actual')
    plt.legend()
    
    # Show plot
    plt.grid(True)
    plt.show()


plot_prediction_vs_actual(y_test, y_pred)
